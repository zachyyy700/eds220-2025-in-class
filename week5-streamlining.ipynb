# %%
import os

import pandas as pd
from pandas.api.types import is_string_dtype, is_numeric_dtype

import geopandas as gpd
import matplotlib.pyplot as plt

pd.set_option("display.max.columns", None)

# %%
# Import power plants data
URL = 'https://raw.githubusercontent.com/carmengg/eds-220-book/refs/heads/main/data/power_plants_epsg4269.csv'
power_plants = pd.read_csv(URL)
power_plants.head()
# Out:
#    Unnamed: 0 objectid plant_code          plant_name utility_id  \
# 0         0.0    11570          1          Sand Point      63560
# 1         1.0    11571          2        Bankhead Dam        195
# 2         2.0    11572          3               Barry        195
# 3         3.0    11573          4  Walter Bouldin Dam        195
# 4         4.0    11574          9              Copper       5701
#
#                      utility_name       sector_name        street_address  \
# 0  TDX Sand Point Generating, LLC  Electric Utility   100 Power Plant Way
# 1                Alabama Power Co  Electric Utility    19001 Lock 17 Road
# 2                Alabama Power Co  Electric Utility      North Highway 43
# 3                Alabama Power Co  Electric Utility  750 Bouldin Dam Road
# 4             El Paso Electric Co  Electric Utility     651 Hawkins Blvd.
#
#          city          county    state      zip     primsource  \
# ...

# %%
# Import states data
fp = os.path.join('data','tl_2022_us_state','tl_2022_us_state.shp')
states = gpd.read_file(fp)
states.head()
# Out:
#   REGION DIVISION STATEFP   STATENS GEOID STUSPS           NAME LSAD  MTFCC  \
# 0      3        5      54  01779805    54     WV  West Virginia   00  G4000
# 1      3        5      12  00294478    12     FL        Florida   00  G4000
# 2      2        3      17  01779784    17     IL       Illinois   00  G4000
# 3      2        4      27  00662849    27     MN      Minnesota   00  G4000
# 4      3        5      24  01714934    24     MD       Maryland   00  G4000
#
#   FUNCSTAT         ALAND       AWATER     INTPTLAT      INTPTLON  \
# 0        A   62266456923    489045863  +38.6472854  -080.6183274
# 1        A  138962819934  45971472526  +28.3989775  -082.5143005
# 2        A  143778515726   6216539665  +40.1028754  -089.1526108
# 3        A  206244837557  18937184315  +46.3159573  -094.1996043
# 4        A   25151771744   6979295311  +38.9466584  -076.6744939
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# ...

# %% [markdown]
# ## CSV to GeoDataFrame

# %%
# Manually create geometries
points = gpd.points_from_xy(power_plants.longitude, 
                            power_plants.latitude)

# Create geodataframe
power_plants = gpd.GeoDataFrame(data = power_plants, 
                                geometry=points,
                                crs="EPSG:4269")

# %%
# Check geometry column
power_plants.geometry.head()
# Out:
# 0    POINT (-160.49722 55.33972)
# 1     POINT (-87.35682 33.45867)
# 2     POINT (-88.01030 31.00690)
# 3     POINT (-86.28306 32.58389)
# 4    POINT (-106.37500 31.75690)
# Name: geometry, dtype: geometry

# %%
# Plot power plants map
power_plants.plot(facecolor='orange',
                  markersize=1,
                  alpha=0.7)
plt.show()

# %% [markdown]
# ## f-strings

# %%
# Use f-string to print info
print(f'Ellipsoid: {power_plants.crs.ellipsoid}')
print(f'Datum: {power_plants.crs.datum}')
# Out:
# Ellipsoid: GRS 1980
# Datum: North American Datum 1983

# %%
# Use f-string to format output
print(f"{'Is the CRS geographic?:':<25} {power_plants.crs.is_geographic}")
print(f"{'Is the CRS projected?:':<25} {power_plants.crs.is_projected}")
# Out:
# Is the CRS geographic?:   True
# Is the CRS projected?:    False

# %% [markdown]
# ## Import shapefile

# %%
# Import states data
fp = os.path.join('data','tl_2022_us_state','tl_2022_us_state.shp')
states = gpd.read_file(fp)

# Simplify column names 
states.columns = states.columns.str.lower()

states.head(3)
# Out:
#   region division statefp   statens geoid stusps           name lsad  mtfcc  \
# 0      3        5      54  01779805    54     WV  West Virginia   00  G4000
# 1      3        5      12  00294478    12     FL        Florida   00  G4000
# 2      2        3      17  01779784    17     IL       Illinois   00  G4000
#
#   funcstat         aland       awater     intptlat      intptlon  \
# 0        A   62266456923    489045863  +38.6472854  -080.6183274
# 1        A  138962819934  45971472526  +28.3989775  -082.5143005
# 2        A  143778515726   6216539665  +40.1028754  -089.1526108
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# 1  MULTIPOLYGON (((-83.10874 24.62949, -83.10711 ...
# 2  POLYGON ((-87.89243 38.28285, -87.89334 38.282...

# %%
# Print states crs
print(f'States CRS = {states.crs}')
# Plot states
states.plot()
plt.show()
# Out:
# States CRS = EPSG:4269

# %% [markdown]
# ### For loop

# %%
# Use forloop to check if dtype is string
code_cols = ['region', 'division', 'statefp']

for column in code_cols:
    print(f"Is {column} column a string? {is_string_dtype(states[column])}")
# Out:
# Is region column a string? True
# Is division column a string? True
# Is statefp column a string? True

# %% [markdown]
# ### `assert`
#
# - `assert` does nothing if adjacent expression is True & raises error if False

# %%
assert 2+2 == 4

# %%
# Update code columns into integers
for column in code_cols:
    states[column] = states[column].astype('int')
    assert is_numeric_dtype(states[column])  # Check conversion

# %% [markdown]
# ## Selecting data
#
# - `df.column.isin()`
#
# - `~`: negates a statement

# %%
# Exclude data
mainland = states[(states.region != 9) & (~states.statefp.isin([2, 15]))]

# %%
# Exclude power plants data
power_plants = power_plants[~power_plants.state.isin(['Hawaii', 'Alaska', 'Puerto Rico'])]

# %%
mainland.crs == power_plants.crs
# Out:
# True

# %% [markdown]
# ## Plotting

# %%
fig, ax = plt.subplots(figsize=(9,5))

# Plot states
mainland.plot(ax=ax,
              color='none',
              edgecolor='black')

# Plot power plants
power_plants.plot(ax=ax,
                  column='primsource',
                  cmap='tab20',
                  legend=True,
                  markersize=3,
                  alpha=0.4,
                  legend_kwds={
                      'title': 'Primary energy source',
                      'title_fontsize': 'small',
                      'fontsize': 'small',
                      'loc': 'upper left',
                      'bbox_to_anchor': (0, 0),
                      'ncol': 6  
                  })

# Remove axes
ax.axis('off')

ax.set_title("Electric Generating Power Plants in the Mainland US")

plt.show()
