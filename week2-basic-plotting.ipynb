# %% [markdown]
# # Pandas Plotting

# %%
import pandas as pd

# Read in file, argument is the file path
df = pd.read_csv('data/wetlands_seasonal_bird_diversity.csv')

# %% [markdown]
# ## Check-In 1

# %%
df.plot(x = 'year',
        y = 'MUL_spring',
        title = "Bird Count at Mugu Lagoon in Spring",
        ylabel='Count',
        xlabel='Year')
# Out:
# <Axes: title={'center': 'Bird Count at Mugu Lagoon in Spring'}, xlabel='Year', ylabel='Count'>

# %%
df[df['MUL_spring'].isna()]
# Out:
#     year  CSM_winter  CSM_spring  CSM_fall  MUL_winter  MUL_spring  MUL_fall  \
# 0   2010        39.0        40.0      50.0        45.0         NaN      61.0
# 10  2020        46.0         NaN      47.0        56.0         NaN      66.0
#
#     SDW_winter  SDW_spring  SDW_fall  TJE_winter  TJE_spring  TJE_fall
# 0          NaN        75.0      85.0         NaN         NaN      81.0
# 10        57.0         NaN      58.0        54.0        40.0      54.0

# %% [markdown]
# ## Check-In 2

# %% [markdown]
# 1. Code breakdown
#
# `df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()`
#
# - The index of df will be set to the `year` column. Then `.loc[]` selects columns from 'SDW_winter' to 'TJE_fall' and then each column gets plotted.

# %%
df.set_index('year').loc[:,'SDW_winter':'TJE_fall'].plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## Check-In 3

# %%
# Read in data
URL = 'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv'
penguins = pd.read_csv(URL)

# %%
penguins[['bill_length_mm', 'bill_depth_mm']].plot(kind='box')
# Out:
# <Axes: >

# %%
subset = penguins[['species', 'sex', 'flipper_length_mm']]
subset[(subset['species'] == 'Gentoo') & (subset['sex'] == 'female')].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
penguins.loc[(penguins['species'] == 'Gentoo') & (penguins['sex'] == 'female'), 'flipper_length_mm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Summary
#
# The `.plot()` method can be chained onto any dataframe, subset, or series to make different types of plots, even with some customizability.
